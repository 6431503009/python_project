# %% [markdown]
# # Lab06 : Data Proprocessing: Data Cleaning and Data Engineering
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  1. Load package
# * **numpy, pandas, seabon**
# * **from sklearn import preprocessing**

# %%
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### 2. Load dataset: creditcard_customer_churn.csv

# %%
##Loading data to data frame
# sort by one column
df = pd.read_csv('creditcard_customer_churn.csv')
df.head(5)
# Out:
#    RowId  CustomerId    CustomerName  CreditScore Geography Income_Category  \
# 0      1  15634602.0     Laura Gomez          619    France     $60K - $80K
# 1      2  15647311.0    Park Min Woo          608     Spain  Less than $40K
# 2      3  15619304.0    Michael Chen          502    France    $80K - $120K
# 3      4  15701354.0     Sofia Rossi          699    France  Less than $40K
# 4      5  15737888.0  Rachel Sanders          850     Spain     $60K - $80K
#
#    Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 0  Female    1/1/1957        Married       0.00          Blue
# 1       M    1/1/1954         Single   83807.86          Blue
# 2    Male    1/1/1965        Married  159660.80          Blue
# 3       F    1/1/1984        Unknown       0.00          Blue
# 4    Male    1/1/1981        Married  125510.82          Blue
#
#    EstimatedSalary Exited
# 0        101348.88    YES
# 1        112542.58     NO
# 2        113931.57    YES
# 3         93826.63     NO
# 4         79084.10     NO

# %% [markdown]
# ### 3. Check null value

# %%
# check null value
df.isnull().sum()
# Out:
# RowId              0
# CustomerId         1
# CustomerName       2
# CreditScore        0
# Geography          1
# Income_Category    0
# Gender             5
# DateOfBirth        0
# Marital_Status     0
# Balance            0
# Card_Category      0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### 4.1 Drop row of column of CustomerId, CustomerName and Gender is "Null"
# * **subset =["CustomerId","CustomerName","Gender"]**

# %%
# Drop subset column "CustomerId"
df.dropna(subset =["CustomerId","CustomerName","Gender"],inplace = True)

# %%
#Check null value
df.isnull().sum()
# Out:
# RowId              0
# CustomerId         0
# CustomerName       0
# CreditScore        0
# Geography          1
# Income_Category    0
# Gender             0
# DateOfBirth        0
# Marital_Status     0
# Balance            0
# Card_Category      0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### 4.2 Drop column ["RowId"],axis=1

# %%
#drop column RowId
df.drop(["RowId"],axis=1,inplace = True)

# %%
df.head(5)
# Out:
#    CustomerId    CustomerName  CreditScore Geography Income_Category  Gender  \
# 0  15634602.0     Laura Gomez          619    France     $60K - $80K  Female
# 1  15647311.0    Park Min Woo          608     Spain  Less than $40K       M
# 2  15619304.0    Michael Chen          502    France    $80K - $120K    Male
# 3  15701354.0     Sofia Rossi          699    France  Less than $40K       F
# 4  15737888.0  Rachel Sanders          850     Spain     $60K - $80K    Male
#
#   DateOfBirth Marital_Status    Balance Card_Category  EstimatedSalary Exited
# 0    1/1/1957        Married       0.00          Blue        101348.88    YES
# 1    1/1/1954         Single   83807.86          Blue        112542.58     NO
# 2    1/1/1965        Married  159660.80          Blue        113931.57    YES
# 3    1/1/1984        Unknown       0.00          Blue         93826.63     NO
# 4    1/1/1981        Married  125510.82          Blue         79084.10     NO

# %% [markdown]
# ### 5. Fill null value "France" in column "Geography"
# * df['DataFrame_Column'] = df['DataFrame_Column'].fillna(0) # fill in missing for a singular colunm

# %%
#Fill "France" value in column "Geography" of null value
df['Geography'] = df['Geography'].fillna(0)

# %%
#Check isnull value
df.isnull().sum()
# Out:
# RowId              0
# CustomerId         1
# CustomerName       2
# CreditScore        0
# Geography          0
# Income_Category    0
# Gender             5
# DateOfBirth        0
# Marital_Status     0
# Balance            0
# Card_Category      0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### 6. Check unique value in each column

# %%
# Check unique value
df.nunique()
# Out:
# RowId              200
# CustomerId         199
# CustomerName       176
# CreditScore        150
# Geography            3
# Income_Category      6
# Gender               2
# DateOfBirth         41
# Marital_Status       4
# Balance            126
# Card_Category        3
# EstimatedSalary    200
# Exited               2
# dtype: int64

# %%
# check column "Gender" in unique value
df.Gender.unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %% [markdown]
# ### 6.1 Plot countplot graph in column "Gender"

# %%
sns.countplot(df.Gender)
# Out:
# C:\Users\first\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### 6.2 Replace value in column Gender from  "M" to "Male" and "F" to "Female"

# %%
df.Gender.replace("M","Male",inplace = True)
df.Gender.replace("F","Female",inplace = True)

# %%
#plot count graph
sns.countplot(df.Gender)
# Out:
# C:\Users\first\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.head()
# Out:
#    RowId  CustomerId    CustomerName  CreditScore Geography Income_Category  \
# 0      1  15634602.0     Laura Gomez          619    France     $60K - $80K
# 1      2  15647311.0    Park Min Woo          608     Spain  Less than $40K
# 2      3  15619304.0    Michael Chen          502    France    $80K - $120K
# 3      4  15701354.0     Sofia Rossi          699    France  Less than $40K
# 4      5  15737888.0  Rachel Sanders          850     Spain     $60K - $80K
#
#    Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 0  Female    1/1/1957        Married       0.00          Blue
# 1    Male    1/1/1954         Single   83807.86          Blue
# 2    Male    1/1/1965        Married  159660.80          Blue
# 3  Female    1/1/1984        Unknown       0.00          Blue
# 4    Male    1/1/1981        Married  125510.82          Blue
#
#    EstimatedSalary Exited
# 0        101348.88    YES
# 1        112542.58     NO
# 2        113931.57    YES
# 3         93826.63     NO
# 4         79084.10     NO

# %% [markdown]
# ### 7.1 Check DataFrame information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       192 non-null    float64
#  1   CustomerName     192 non-null    object
#  2   CreditScore      192 non-null    int64
#  3   Geography        192 non-null    object
#  4   Income_Category  192 non-null    object
#  5   Gender           192 non-null    object
#  6   DateOfBirth      192 non-null    object
#  7   Marital_Status   192 non-null    object
#  8   Balance          192 non-null    float64
#  9   Card_Category    192 non-null    object
#  10  EstimatedSalary  192 non-null    float64
#  11  Exited           192 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 19.5+ KB

# %% [markdown]
# ### 7.2 Change Type of CustomerId from float to int by using
# * **"ColumnName.astype(int)"**

# %%
#change datatype "CustomerId" :  is integer
df['CustomerId'] = df.CustomerId.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       192 non-null    int32
#  1   CustomerName     192 non-null    object
#  2   CreditScore      192 non-null    int64
#  3   Geography        192 non-null    object
#  4   Income_Category  192 non-null    object
#  5   Gender           192 non-null    object
#  6   DateOfBirth      192 non-null    object
#  7   Marital_Status   192 non-null    object
#  8   Balance          192 non-null    float64
#  9   Card_Category    192 non-null    object
#  10  EstimatedSalary  192 non-null    float64
#  11  Exited           192 non-null    object
# dtypes: float64(2), int32(1), int64(1), object(8)
# memory usage: 18.8+ KB

# %% [markdown]
# ### 7.3 Change Type of DateOfBirth from object to DateTime by using
# * **"columnName = pd.to_datetime(columnName)"**

# %%
#Change "DateOfBirth" in datatype of datetime
df['DateOfBirth'] = pd.to_datetime(df['DateOfBirth'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       192 non-null    int32
#  1   CustomerName     192 non-null    object
#  2   CreditScore      192 non-null    int64
#  3   Geography        192 non-null    object
#  4   Income_Category  192 non-null    object
#  5   Gender           192 non-null    object
#  6   DateOfBirth      192 non-null    datetime64[ns]
#  7   Marital_Status   192 non-null    object
#  8   Balance          192 non-null    float64
#  9   Card_Category    192 non-null    object
#  10  EstimatedSalary  192 non-null    float64
#  11  Exited           192 non-null    object
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(7)
# memory usage: 18.8+ KB

# %%
df.head()
# Out:
#    CustomerId    CustomerName  CreditScore Geography Income_Category  Gender  \
# 0    15634602     Laura Gomez          619    France     $60K - $80K  Female
# 1    15647311    Park Min Woo          608     Spain  Less than $40K    Male
# 2    15619304    Michael Chen          502    France    $80K - $120K    Male
# 3    15701354     Sofia Rossi          699    France  Less than $40K  Female
# 4    15737888  Rachel Sanders          850     Spain     $60K - $80K    Male
#
#   DateOfBirth Marital_Status    Balance Card_Category  EstimatedSalary Exited
# 0  1957-01-01        Married       0.00          Blue        101348.88    YES
# 1  1954-01-01         Single   83807.86          Blue        112542.58     NO
# 2  1965-01-01        Married  159660.80          Blue        113931.57    YES
# 3  1984-01-01        Unknown       0.00          Blue         93826.63     NO
# 4  1981-01-01        Married  125510.82          Blue         79084.10     NO

# %% [markdown]
# ### 7.1 Sort by CustomerName
# * **DataFrame.sort_values(by=[column], ascending =True, inplace = True)**

# %%
#Sort by Cutomer Name
df.sort_values(by=['CustomerName'], ascending =True, inplace = True)
df.head()
# Out:
#      CustomerId   CustomerName  CreditScore Geography Income_Category  Gender  \
# 125    15627360  Adam Odonnell          432    France     $60K - $80K    Male
# 17     15788218       Alex Kim          549     Spain    $80K - $120K  Female
# 59     15804771        Alex Ng          614    France     $60K - $80K    Male
# 60     15651280    Alice Smith          742   Germany    $80K - $120K    Male
# 21     15597945    Amanda Chen          636     Spain  Less than $40K  Female
#
#     DateOfBirth Marital_Status    Balance Card_Category  EstimatedSalary  \
# 125  1976-01-01         Single  152603.45          Blue        110265.24
# 17   1946-01-01        Married       0.00          Blue         14406.41
# 59   1968-01-01         Single   40685.92          Blue         46775.28
# 60   1982-01-01        Married  136857.00          Blue         84509.57
# 21   1979-01-01        Married       0.00          Blue        138555.46
#
#     Exited
# 125    YES
# 17      NO
# 59      NO
# 60      NO
# 21      NO

# %% [markdown]
# ### 7.2 Create a new DataFrame "df_query" from -> Query data by Geography is "Spain"
# * **DataFrame.query(“ condition ”, inplace = True)**

# %%
#Create new Data Frame from Query data by Geography is "Spain
df.query("Geography == 'Spain'", inplace = True)
df.head()
# Out:
#      CustomerId     CustomerName  CreditScore Geography Income_Category  \
# 17     15788218         Alex Kim          549     Spain    $80K - $120K
# 21     15597945      Amanda Chen          636     Spain  Less than $40K
# 196    15635905    Ana Hernandez          616     Spain         $120K +
# 175    15755209  Cameron Leonard          484     Spain     $40K - $60K
# 139    15640905      Carol Jones          579     Spain  Less than $40K
#
#      Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 17   Female  1946-01-01        Married       0.00          Blue
# 21   Female  1979-01-01        Married       0.00          Blue
# 196  Female  1972-01-01        Unknown       0.00          Blue
# 175  Female  1972-01-01       Divorced  133868.21          Blue
# 139  Female  1980-01-01         Single  129490.36          Blue
#
#      EstimatedSalary Exited
# 17          14406.41     NO
# 21         138555.46     NO
# 196         43001.46     NO
# 175         27286.10     NO
# 139          8590.83    YES

# %% [markdown]
# ### 7.3 From df_query : Filter column in "CustomerId", "CustomerName","Income_Category","Gender" and "Exited"
# * **DataFrame.filter([column])**

# %%
#Filter column in "CustomerId", "CustomerName","Income_Category","Gender" and "Exited"
df.filter(["CustomerId", "CustomerName","Income_Category","Gender" , "Exited"])
df.head()
# Out:
#      CustomerId     CustomerName  CreditScore Geography Income_Category  \
# 17     15788218         Alex Kim          549     Spain    $80K - $120K
# 21     15597945      Amanda Chen          636     Spain  Less than $40K
# 196    15635905    Ana Hernandez          616     Spain         $120K +
# 175    15755209  Cameron Leonard          484     Spain     $40K - $60K
# 139    15640905      Carol Jones          579     Spain  Less than $40K
#
#      Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 17   Female  1946-01-01        Married       0.00          Blue
# 21   Female  1979-01-01        Married       0.00          Blue
# 196  Female  1972-01-01        Unknown       0.00          Blue
# 175  Female  1972-01-01       Divorced  133868.21          Blue
# 139  Female  1980-01-01         Single  129490.36          Blue
#
#      EstimatedSalary Exited
# 17          14406.41     NO
# 21         138555.46     NO
# 196         43001.46     NO
# 175         27286.10     NO
# 139          8590.83    YES

# %% [markdown]
# ## 8: Data Transformation: Feature Engineering
# ### 8.1 : Using [ ] to add a new column From datafram df
# * **Create new column in "BirthYear" from column "DateOfBirth"

# %%
# Create column "BirthYear" from split data from column "DateOfBirth"
df['BirthYear'] = df['DateOfBirth'].dt.year
df.head()
# Out:
#      CustomerId     CustomerName  CreditScore Geography Income_Category  \
# 17     15788218         Alex Kim          549     Spain    $80K - $120K
# 21     15597945      Amanda Chen          636     Spain  Less than $40K
# 196    15635905    Ana Hernandez          616     Spain         $120K +
# 175    15755209  Cameron Leonard          484     Spain     $40K - $60K
# 139    15640905      Carol Jones          579     Spain  Less than $40K
#
#      Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 17   Female  1946-01-01        Married       0.00          Blue
# 21   Female  1979-01-01        Married       0.00          Blue
# 196  Female  1972-01-01        Unknown       0.00          Blue
# 175  Female  1972-01-01       Divorced  133868.21          Blue
# 139  Female  1980-01-01         Single  129490.36          Blue
#
#      EstimatedSalary Exited  BirthYear
# 17          14406.41     NO       1946
# 21         138555.46     NO       1979
# 196         43001.46     NO       1972
# 175         27286.10     NO       1972
# 139          8590.83    YES       1980

# %% [markdown]
# ### 8.2: Create new column "Age" from Current DataTime -  BirthYear
# * **import package: from datetime import datetime as dt
# * **convert type to interger using fuction astype(int)

# %%
from datetime import datetime as dt
Current_DateTime = dt.today().year
print(Current_DateTime)
# Out:
# 2023

# %%
# Create column "Age" from Current DataTime - BirthYear
df['Age'] = Current_DateTime - df['BirthYear']

# %%
#show 5 first rows
df.head()
# Out:
#      CustomerId     CustomerName  CreditScore Geography Income_Category  \
# 17     15788218         Alex Kim          549     Spain    $80K - $120K
# 21     15597945      Amanda Chen          636     Spain  Less than $40K
# 196    15635905    Ana Hernandez          616     Spain         $120K +
# 175    15755209  Cameron Leonard          484     Spain     $40K - $60K
# 139    15640905      Carol Jones          579     Spain  Less than $40K
#
#      Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 17   Female  1946-01-01        Married       0.00          Blue
# 21   Female  1979-01-01        Married       0.00          Blue
# 196  Female  1972-01-01        Unknown       0.00          Blue
# 175  Female  1972-01-01       Divorced  133868.21          Blue
# 139  Female  1980-01-01         Single  129490.36          Blue
#
#      EstimatedSalary Exited  BirthYear  Age
# 17          14406.41     NO       1946   77
# 21         138555.46     NO       1979   44
# 196         43001.46     NO       1972   51
# 175         27286.10     NO       1972   51
# 139          8590.83    YES       1980   43

# %% [markdown]
# ### 8.3: Using apply() function used to manipulate values
# * **#Create column "FirstName" to split data from feature "CustomerName"**
# * **df['FirstName'] = df.apply(lambda row: splitFullName(row.CustomerName), axis=1)**

# %%
# Function split Full name to FirstName and LastName, then return FirstName
def splitFullName(name):
    split = name.split(' ')
    firstName= split[0]
    return firstName

# %%
#Create column "FirstName" to split data from feature "CustomerName"
df['FirstName'] = df.apply(lambda row: splitFullName(row.CustomerName), axis=1)
df.head()
# df['FirstName'] = df.apply(row.CustomerName,axis = 1)
# Out:
#      CustomerId     CustomerName  CreditScore Geography Income_Category  \
# 17     15788218         Alex Kim          549     Spain    $80K - $120K
# 21     15597945      Amanda Chen          636     Spain  Less than $40K
# 196    15635905    Ana Hernandez          616     Spain         $120K +
# 175    15755209  Cameron Leonard          484     Spain     $40K - $60K
# 139    15640905      Carol Jones          579     Spain  Less than $40K
#
#      Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 17   Female  1946-01-01        Married       0.00          Blue
# 21   Female  1979-01-01        Married       0.00          Blue
# 196  Female  1972-01-01        Unknown       0.00          Blue
# 175  Female  1972-01-01       Divorced  133868.21          Blue
# 139  Female  1980-01-01         Single  129490.36          Blue
#
#      EstimatedSalary Exited  BirthYear  Age FirstName
# 17          14406.41     NO       1946   77      Alex
# 21         138555.46     NO       1979   44    Amanda
# 196         43001.46     NO       1972   51       Ana
# 175         27286.10     NO       1972   51   Cameron
# 139          8590.83    YES       1980   43     Carol

# %% [markdown]
# ### 8.4: Using transform() function used to manipulate values
# * **#Create column "LastName" to split data from feature "CustomerName"**
# * **df['LastName'] = df['CustomerName'].transform(lambda row: row.split(' ')[1])**

# %%
# Create column "FirstName" to split data from feature "CustomerName"
# Using lambda equivalent
df['LastName'] = df['CustomerName'].transform(lambda row: row.split(' ')[1])
df.head()
# Out:
#      CustomerId     CustomerName  CreditScore Geography Income_Category  \
# 17     15788218         Alex Kim          549     Spain    $80K - $120K
# 21     15597945      Amanda Chen          636     Spain  Less than $40K
# 196    15635905    Ana Hernandez          616     Spain         $120K +
# 175    15755209  Cameron Leonard          484     Spain     $40K - $60K
# 139    15640905      Carol Jones          579     Spain  Less than $40K
#
#      Gender DateOfBirth Marital_Status    Balance Card_Category  \
# 17   Female  1946-01-01        Married       0.00          Blue
# 21   Female  1979-01-01        Married       0.00          Blue
# 196  Female  1972-01-01        Unknown       0.00          Blue
# 175  Female  1972-01-01       Divorced  133868.21          Blue
# 139  Female  1980-01-01         Single  129490.36          Blue
#
#      EstimatedSalary Exited  BirthYear  Age FirstName   LastName
# 17          14406.41     NO       1946   77      Alex        Kim
# 21         138555.46     NO       1979   44    Amanda       Chen
# 196         43001.46     NO       1972   51       Ana  Hernandez
# 175         27286.10     NO       1972   51   Cameron    Leonard
# 139          8590.83    YES       1980   43     Carol      Jones

# %% [markdown]
# ### 8.5: Drop column "CustomerId", "CustomerName" and "DateOfBirth"
# * **.drop([],axis=1,inplace=True)**

# %%
#Drop column "CustomerId", "CustomerName" and "DateOfBirth"
df.head()
df.drop(["CustomerId","CustomerName","DateOfBirth"],axis=1,inplace=True)

# %%
df.head()
# Out:
#      CreditScore Geography Income_Category  Gender Marital_Status    Balance  \
# 17           549     Spain    $80K - $120K  Female        Married       0.00
# 21           636     Spain  Less than $40K  Female        Married       0.00
# 196          616     Spain         $120K +  Female        Unknown       0.00
# 175          484     Spain     $40K - $60K  Female       Divorced  133868.21
# 139          579     Spain  Less than $40K  Female         Single  129490.36
#
#     Card_Category  EstimatedSalary Exited  BirthYear  Age FirstName   LastName
# 17           Blue         14406.41     NO       1946   77      Alex        Kim
# 21           Blue        138555.46     NO       1979   44    Amanda       Chen
# 196          Blue         43001.46     NO       1972   51       Ana  Hernandez
# 175          Blue         27286.10     NO       1972   51   Cameron    Leonard
# 139          Blue          8590.83    YES       1980   43     Carol      Jones

# %% [markdown]
# ### 9.1. Encoding Categorical Features: One-hot encoding
# * **Using dummies values approach: df2 = pandas.get_dummies(df[columnName])**
# * **Using pandas concat function for concatenating pandas object into Dataframe output**
# * **df = pd.concat([df,df2],axis=1)**

# %%
#Transform column "Gender" all the labels 'Male', 'Female' into 1,0 binary columns
df2 = pd.get_dummies(df['Gender'])
df2.head()
# Out:
#      Female  Male
# 17        1     0
# 21        1     0
# 196       1     0
# 175       1     0
# 139       1     0

# %%
#Using pandas concat() function for concatenating pandas objects into a Data Frame output.
df = pd.concat([df,df2],axis = 1)

# %%
df.head()
# Out:
#      CreditScore Geography Income_Category  Gender Marital_Status    Balance  \
# 17           549     Spain    $80K - $120K  Female        Married       0.00
# 21           636     Spain  Less than $40K  Female        Married       0.00
# 196          616     Spain         $120K +  Female        Unknown       0.00
# 175          484     Spain     $40K - $60K  Female       Divorced  133868.21
# 139          579     Spain  Less than $40K  Female         Single  129490.36
#
#     Card_Category  EstimatedSalary Exited  BirthYear  Age FirstName  \
# 17           Blue         14406.41     NO       1946   77      Alex
# 21           Blue        138555.46     NO       1979   44    Amanda
# 196          Blue         43001.46     NO       1972   51       Ana
# 175          Blue         27286.10     NO       1972   51   Cameron
# 139          Blue          8590.83    YES       1980   43     Carol
#
#       LastName  Female  Male
# 17         Kim       1     0
# 21        Chen       1     0
# 196  Hernandez       1     0
# 175    Leonard       1     0
# 139      Jones       1     0

# %% [markdown]
# ### 9.2. One-hot encoding :: using Scikit learn
# * **Using sci-kit learn library values approach: column "Marital_Status"**
# * **encoder = preprocessing.OneHotEncoder()**
# * **encoder_features = pd.DataFrame(encoder.fit_transform(df[['Marital_Status']]).toarray()**
# * **df.join(encoder_features)**

# %%
#creating instance of one-hot-encoder
encoder = preprocessing.OneHotEncoder()

#perform one-hot encoding on 'team' column 
encoder_features = pd.DataFrame(encoder.fit_transform(df[['Marital_Status']]).toarray())

#merge one-hot encoded columns back with original DataFrame
final_df = df.join(encoder_features)
final_df.head()
# Out:
#      CreditScore Geography Income_Category  Gender Marital_Status    Balance  \
# 17           549     Spain    $80K - $120K  Female        Married       0.00
# 21           636     Spain  Less than $40K  Female        Married       0.00
# 196          616     Spain         $120K +  Female        Unknown       0.00
# 175          484     Spain     $40K - $60K  Female       Divorced  133868.21
# 139          579     Spain  Less than $40K  Female         Single  129490.36
#
#     Card_Category  EstimatedSalary Exited  BirthYear  Age FirstName  \
# 17           Blue         14406.41     NO       1946   77      Alex
# 21           Blue        138555.46     NO       1979   44    Amanda
# 196          Blue         43001.46     NO       1972   51       Ana
# 175          Blue         27286.10     NO       1972   51   Cameron
# 139          Blue          8590.83    YES       1980   43     Carol
#
#       LastName  Female  Male    0    1    2    3
# 17         Kim       1     0  0.0  1.0  0.0  0.0
# 21        Chen       1     0  1.0  0.0  0.0  0.0
# 196  Hernandez       1     0  NaN  NaN  NaN  NaN
# 175    Leonard       1     0  NaN  NaN  NaN  NaN
# 139      Jones       1     0  NaN  NaN  NaN  NaN

# %%
final_df['Marital_Status'].unique()
# Out:
# array(['Married', 'Unknown', 'Divorced', 'Single'], dtype=object)

# %% [markdown]
# ### 9.3. Rename colunm
# * **{0:'Single', 1:'Married', 2:'Unknown', 3:'Divorced'}, axis=1**

# %%
#Rename colunm 0,1,2,3 to 'Single', 'Married', 'Unknown', 'Divorced'
final_df.rename({0:'Single', 1:'Married', 2:'Unknown', 3:'Divorced'}, axis=1,inplace = True)
df.head()
# Out:
#      CreditScore Geography Income_Category  Gender Marital_Status    Balance  \
# 17           549     Spain    $80K - $120K  Female        Married       0.00
# 21           636     Spain  Less than $40K  Female        Married       0.00
# 196          616     Spain         $120K +  Female        Unknown       0.00
# 175          484     Spain     $40K - $60K  Female       Divorced  133868.21
# 139          579     Spain  Less than $40K  Female         Single  129490.36
#
#     Card_Category  EstimatedSalary Exited  BirthYear  Age FirstName  \
# 17           Blue         14406.41     NO       1946   77      Alex
# 21           Blue        138555.46     NO       1979   44    Amanda
# 196          Blue         43001.46     NO       1972   51       Ana
# 175          Blue         27286.10     NO       1972   51   Cameron
# 139          Blue          8590.83    YES       1980   43     Carol
#
#       LastName  Female  Male
# 17         Kim       1     0
# 21        Chen       1     0
# 196  Hernandez       1     0
# 175    Leonard       1     0
# 139      Jones       1     0

# %% [markdown]
# ### 9.4.  Label Encoding : categorical column "Card_Category"
# * **converting type of columns to 'category'**
# * **df_final['Card_Category'] = df_final['Card_Category'].astype('category')**
# * **Assigning numerical values and storing in another column**
# * **final_df['Card_Cat_Label'] = final_df['Card_Category'].cat.codes**

# %%
# converting type of columns to 'category'
final_df['Card_Category'] = final_df['Card_Category'].astype('category')

# Assigning numerical values and storing in another column
final_df['Card_Cat_Label'] = final_df['Card_Category'].cat.codes

# %%
final_df.head()
# Out:
#      CreditScore Geography Income_Category  Gender Marital_Status    Balance  \
# 17           549     Spain    $80K - $120K  Female        Married       0.00
# 21           636     Spain  Less than $40K  Female        Married       0.00
# 196          616     Spain         $120K +  Female        Unknown       0.00
# 175          484     Spain     $40K - $60K  Female       Divorced  133868.21
# 139          579     Spain  Less than $40K  Female         Single  129490.36
#
#     Card_Category  EstimatedSalary Exited  BirthYear  Age FirstName  \
# 17           Blue         14406.41     NO       1946   77      Alex
# 21           Blue        138555.46     NO       1979   44    Amanda
# 196          Blue         43001.46     NO       1972   51       Ana
# 175          Blue         27286.10     NO       1972   51   Cameron
# 139          Blue          8590.83    YES       1980   43     Carol
#
#       LastName  Female  Male  Single  Married  Unknown  Divorced  \
# 17         Kim       1     0     0.0      1.0      0.0       0.0
# 21        Chen       1     0     1.0      0.0      0.0       0.0
# 196  Hernandez       1     0     NaN      NaN      NaN       NaN
# 175    Leonard       1     0     NaN      NaN      NaN       NaN
# 139      Jones       1     0     NaN      NaN      NaN       NaN
#
#      Card_Cat_Label
# 17                0
# 21                0
# 196               0
# 175               0
# 139               0

# %% [markdown]
# ### 9.5.  Label Encoding : scikit Learn
# * **column "Exited"**
# * **labelencoder = preprocessing.LabelEncoder()**
# * **df_final['Exited_Label'] = labelencoder.fit_transform(df_final['Exited'])**

# %%
# creating instance of labelencoder
labelencoder = preprocessing.LabelEncoder()

# Assigning numerical values and storing in another column
final_df['Exited_Label'] = labelencoder.fit_transform(final_df['Exited'])

# %%
final_df.head()
# Out:
#      CreditScore Geography Income_Category  Gender Marital_Status    Balance  \
# 17           549     Spain    $80K - $120K  Female        Married       0.00
# 21           636     Spain  Less than $40K  Female        Married       0.00
# 196          616     Spain         $120K +  Female        Unknown       0.00
# 175          484     Spain     $40K - $60K  Female       Divorced  133868.21
# 139          579     Spain  Less than $40K  Female         Single  129490.36
#
#     Card_Category  EstimatedSalary Exited  BirthYear  ...  FirstName  \
# 17           Blue         14406.41     NO       1946  ...       Alex
# 21           Blue        138555.46     NO       1979  ...     Amanda
# 196          Blue         43001.46     NO       1972  ...        Ana
# 175          Blue         27286.10     NO       1972  ...    Cameron
# 139          Blue          8590.83    YES       1980  ...      Carol
#
#       LastName Female  Male  Single  Married  Unknown  Divorced  \
# 17         Kim      1     0     0.0      1.0      0.0       0.0
# 21        Chen      1     0     1.0      0.0      0.0       0.0
# 196  Hernandez      1     0     NaN      NaN      NaN       NaN
# 175    Leonard      1     0     NaN      NaN      NaN       NaN
# 139      Jones      1     0     NaN      NaN      NaN       NaN
#
#      Card_Cat_Label  Exited_Label
# 17                0             0
# 21                0             0
# 196               0             0
# 175               0             0
# 139               0             1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 9.6 : Create a new datframe df_normalize
# * **Select only column [["Balance","EstimatedSalary","Gender_Female","Gender_Male",	"Single","Card_Cat_Label", "Exited_Label"]] from df_final**

# %%
df_normalize = final_df[["Balance","EstimatedSalary","Female","Male","Single","Card_Cat_Label","Exited_Label"]]
df_normalize.head()
# Out:
#        Balance  EstimatedSalary  Female  Male  Single  Card_Cat_Label  \
# 17        0.00         14406.41       1     0     0.0               0
# 21        0.00        138555.46       1     0     1.0               0
# 196       0.00         43001.46       1     0     NaN               0
# 175  133868.21         27286.10       1     0     NaN               0
# 139  129490.36          8590.83       1     0     NaN               0
#
#      Exited_Label
# 17              0
# 21              0
# 196             0
# 175             0
# 139             1

# %% [markdown]
# ### 9.7 Feature Scaling
# * **Create a scaler object: scaler = preprocessing.MinMaxScaler()**
# * **Fit and transform the data: df_normalize = pd.DataFrame(scaler.fit_transform(df_normalize), columns=df_normalize.columns)**

# %%
# create a scaler object
scaler = preprocessing.MinMaxScaler()

# %%
# fit and transform the data
df_normalize = pd.DataFrame(scaler.fit_transform(df_normalize), columns=df_normalize.columns)

# %%
#Show last 10 rows
df_normalize.tail(10)
# Out:
#      Balance  EstimatedSalary  Female  Male  Single  Card_Cat_Label  \
# 45  0.000000         0.808187     0.0   1.0     NaN             0.0
# 46  0.511448         1.000000     1.0   0.0     NaN             0.0
# 47  0.474136         0.426243     1.0   0.0     NaN             0.0
# 48  0.000000         0.330030     1.0   0.0     0.0             0.0
# 49  0.000000         0.000000     1.0   0.0     NaN             0.0
# 50  0.000000         0.200548     1.0   0.0     NaN             0.0
# 51  0.570884         0.651762     0.0   1.0     NaN             0.0
# 52  0.478512         0.477946     1.0   0.0     NaN             1.0
# 53  0.000000         0.580080     1.0   0.0     NaN             0.0
# 54  0.482427         0.323069     0.0   1.0     NaN             0.0
#
#     Exited_Label
# 45           1.0
# 46           0.0
# 47           0.0
# 48           0.0
# 49           1.0
# 50           1.0
# 51           1.0
# 52           0.0
# 53           0.0
# 54           0.0
